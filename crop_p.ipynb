# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Crop_production.csv.xls')

# %%
df
# Out:
#        Unnamed: 0      State_Name Crop_Type       Crop    N   P   K    pH  \
# 0               0  andhra pradesh    kharif     cotton  120  40  20  5.46
# 1               1  andhra pradesh    kharif  horsegram   20  60  20  6.18
# 2               2  andhra pradesh    kharif      jowar   80  40  40  5.42
# 3               3  andhra pradesh    kharif      maize   80  40  20  5.62
# 4               4  andhra pradesh    kharif      moong   20  40  20  5.68
# ...           ...             ...       ...        ...  ...  ..  ..   ...
# 99844       99844     west bengal      rabi      wheat   60  30  30  6.70
# 99845       99845     west bengal    summer      maize   80  40  20  5.68
# 99846       99846     west bengal    summer       rice   80  40  40  5.64
# 99847       99847     west bengal      rabi       rice   80  40  40  5.42
# 99848       99848     west bengal      rabi    sesamum   30  15  30  6.54
#
#        rainfall  temperature  Area_in_hectares  Production_in_tons  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             N             P             K            pH  \
# count  99849.000000  99849.000000  99849.000000  99849.000000  99849.000000
# mean   49924.000000     69.816823     41.593656     42.037827      5.643624
# std    28824.067851     39.571469     15.056508     28.430263      0.505283
# min        0.000000     10.000000     10.000000     10.000000      3.820000
# 25%    24962.000000     50.000000     40.000000     20.000000      5.360000
# 50%    49924.000000     75.000000     40.000000     30.000000      5.540000
# 75%    74886.000000     80.000000     60.000000     50.000000      5.960000
# max    99848.000000    180.000000    125.000000    200.000000      7.000000
#
#            rainfall   temperature  Area_in_hectares  Production_in_tons  \
# count  99849.000000  99849.000000      99849.000000        9.984900e+04
# mean     701.151085     26.684154      16476.585668        3.776291e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99849 entries, 0 to 99848
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          99849 non-null  int64
#  1   State_Name          99849 non-null  object
#  2   Crop_Type           99849 non-null  object
#  3   Crop                99849 non-null  object
#  4   N                   99849 non-null  int64
#  5   P                   99849 non-null  int64
#  6   K                   99849 non-null  int64
#  7   pH                  99849 non-null  float64
#  8   rainfall            99849 non-null  float64
#  9   temperature         99849 non-null  float64
#  10  Area_in_hectares    99849 non-null  float64
#  11  Production_in_tons  99849 non-null  float64
#  12  Yield_ton_per_hec   99849 non-null  float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 9.9+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# State_Name            0
# Crop_Type             0
# Crop                  0
# N                     0
# P                     0
# K                     0
# pH                    0
# rainfall              0
# temperature           0
# Area_in_hectares      0
# Production_in_tons    0
# Yield_ton_per_hec     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## visual representaion

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Crop_Type', hue="Crop_Type",palette='bright')
plt.title('Amount of production')
plt.xlabel('Crop_Type')
plt.ylabel('Amount of Crops')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Crop_Type', y='Production_in_tons', estimator='sum', ci=None)
plt.title('Production of crop in tons')
plt.xlabel('Crop_Type')
plt.ylabel('Total Production(in tons)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,7))
plt.scatter(x=df['Crop'],y=df['Crop_Type'])
plt.xlabel('Crops')
plt.ylabel('Seasonaly Production')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(20, 12))
for i, column in enumerate(df.select_dtypes(include='number'),1):
    plt.subplot(4,4,i)
    sns.boxplot(df[column])

# %%
plt.figure(figsize=(20, 12))
for i, column in enumerate(df.select_dtypes(include='number'),1):
    plt.subplot(4,4,i)
    sns.distplot(df[column])

# %%
for i in df.select_dtypes(include='number'):
    skewness=df[i].skew()
    print("The skewness of",i,"is",skewness)
# Out:
# The skewness of Unnamed: 0 is 0.0
# The skewness of N is 0.9120064218945413
# The skewness of P is 0.12088188715679513
# The skewness of K is 1.7543017217976704
# The skewness of pH is 0.5713473146626111
# The skewness of rainfall is 1.144965352395372
# The skewness of temperature is -0.7647918034325745
# The skewness of Area_in_hectares is 4.756931689750546
# The skewness of Production_in_tons is 7.225425192424246
# The skewness of Yield_ton_per_hec is 247.60525970553357

# %% [markdown]
# ## Correlation and heatmap

# %%
df.describe(include='object')
# Out:
#            State_Name Crop_Type   Crop
# count           99849     99849  99849
# unique             33         4     53
# top     uttar pradesh    kharif   rice
# freq            12598     38758  11430

# %%
df=df.drop(["Crop_Type","Crop"],axis=1)
df
# Out:
#        Unnamed: 0      State_Name    N   P   K    pH  rainfall  temperature  \
# 0               0  andhra pradesh  120  40  20  5.46    654.34    29.266667
# 1               1  andhra pradesh   20  60  20  6.18    654.34    29.266667
# 2               2  andhra pradesh   80  40  40  5.42    654.34    29.266667
# 3               3  andhra pradesh   80  40  20  5.62    654.34    29.266667
# 4               4  andhra pradesh   20  40  20  5.68    654.34    29.266667
# ...           ...             ...  ...  ..  ..   ...       ...          ...
# 99844       99844     west bengal   60  30  30  6.70    152.54    22.280000
# 99845       99845     west bengal   80  40  20  5.68    182.50    29.200000
# 99846       99846     west bengal   80  40  40  5.64    182.50    29.200000
# 99847       99847     west bengal   80  40  40  5.42    152.54    22.280000
# 99848       99848     west bengal   30  15  30  6.54    152.54    22.280000
#
# ...

# %%
df=df.drop(["State_Name"],axis=1)
df
# Out:
#        Unnamed: 0    N   P   K    pH  rainfall  temperature  Area_in_hectares  \
# 0               0  120  40  20  5.46    654.34    29.266667            7300.0
# 1               1   20  60  20  6.18    654.34    29.266667            3300.0
# 2               2   80  40  40  5.42    654.34    29.266667           10100.0
# 3               3   80  40  20  5.62    654.34    29.266667            2800.0
# 4               4   20  40  20  5.68    654.34    29.266667            1300.0
# ...           ...  ...  ..  ..   ...       ...          ...               ...
# 99844       99844   60  30  30  6.70    152.54    22.280000            2013.0
# 99845       99845   80  40  20  5.68    182.50    29.200000             258.0
# 99846       99846   80  40  40  5.64    182.50    29.200000             105.0
# 99847       99847   80  40  40  5.42    152.54    22.280000          152676.0
# 99848       99848   30  15  30  6.54    152.54    22.280000             244.0
#
# ...

# %%
df.corr()
# Out:
#                     Unnamed: 0         N         P         K        pH  \
# Unnamed: 0            1.000000  0.011618  0.004737  0.005913 -0.003418
# N                     0.011618  1.000000  0.342521  0.486650 -0.235437
# P                     0.004737  0.342521  1.000000  0.210349 -0.254776
# K                     0.005913  0.486650  0.210349  1.000000 -0.246708
# pH                   -0.003418 -0.235437 -0.254776 -0.246708  1.000000
# rainfall             -0.044061  0.111900  0.110686  0.369173 -0.021997
# temperature          -0.024922 -0.044755 -0.056988 -0.078606  0.012203
# Area_in_hectares     -0.002755  0.009287 -0.057514 -0.120388  0.060136
# Production_in_tons    0.022509  0.097888 -0.010698 -0.026379  0.073654
# Yield_ton_per_hec     0.006756  0.090223  0.076806  0.076198  0.006427
#
#                     rainfall  temperature  Area_in_hectares  \
# Unnamed: 0         -0.044061    -0.024922         -0.002755
# N                   0.111900    -0.044755          0.009287
# ...

# %%
plt.figure(figsize=(14, 7))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Checking for Outliers

# %%
df.shape
# Out:
# (99849, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# N                       int64
# P                       int64
# K                       int64
# pH                    float64
# rainfall              float64
# temperature           float64
# Area_in_hectares      float64
# Production_in_tons    float64
# Yield_ton_per_hec     float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          Unnamed: 0             N             P             K            pH  \
# count  99849.000000  99849.000000  99849.000000  99849.000000  99849.000000
# mean   49924.000000     69.816823     41.593656     42.037827      5.643624
# std    28824.067851     39.571469     15.056508     28.430263      0.505283
# min        0.000000     10.000000     10.000000     10.000000      3.820000
# 25%    24962.000000     50.000000     40.000000     20.000000      5.360000
# 50%    49924.000000     75.000000     40.000000     30.000000      5.540000
# 75%    74886.000000     80.000000     60.000000     50.000000      5.960000
# max    99848.000000    180.000000    125.000000    200.000000      7.000000
#
#            rainfall   temperature  Area_in_hectares  Production_in_tons  \
# count  99849.000000  99849.000000      99849.000000        9.984900e+04
# mean     701.151085     26.684154      16476.585668        3.776291e+04
# ...

# %% [markdown]
# ## Treatement of Outliers

# %%
q1=df.quantile(0.25)
q1
# Out:
# Unnamed: 0            24962.000000
# N                        50.000000
# P                        40.000000
# K                        20.000000
# pH                        5.360000
# rainfall                157.310000
# temperature              23.106000
# Area_in_hectares        130.000000
# Production_in_tons      162.000000
# Yield_ton_per_hec         0.586207
# Name: 0.25, dtype: float64

# %%
q3=df.quantile(0.75)
q3
# Out:
# Unnamed: 0            74886.000000
# N                        80.000000
# P                        60.000000
# K                        50.000000
# pH                        5.960000
# rainfall               1110.780000
# temperature              29.266667
# Area_in_hectares       8099.000000
# Production_in_tons    14395.000000
# Yield_ton_per_hec         2.997288
# Name: 0.75, dtype: float64

# %%
IQR = q3-q1
IQR
# Out:
# Unnamed: 0            49924.000000
# N                        30.000000
# P                        20.000000
# K                        30.000000
# pH                        0.600000
# rainfall                953.470000
# temperature               6.160667
# Area_in_hectares       7969.000000
# Production_in_tons    14233.000000
# Yield_ton_per_hec         2.411081
# dtype: float64

# %%
n_high= q3.N+(1.5*IQR.N)
n_high
# Out:
# np.float64(125.0)

# %%
n_low= q1.N-(1.5*IQR.N)
n_low
# Out:
# np.float64(5.0)

# %%
import numpy as np
new_df = df.copy()
new_df['N']=np.where(new_df['N']>n_high,
                    n_high,
                    np.where(new_df['N']<n_low,
                    n_low,
                    new_df['N']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['N'])

plt.subplot(2,2,2)
sns.boxplot(df['N'])

plt.subplot(2,2,3)
sns.distplot(new_df['N'])

plt.subplot(2,2,4)
sns.boxplot(new_df['N'])

plt.show()

# %%
p_high= q3.P+(1.5*IQR.P)
p_high
# Out:
# np.float64(90.0)

# %%
p_low= q1.P-(1.5*IQR.P)
p_low
# Out:
# np.float64(10.0)

# %%
new_df['P']=np.where(new_df['P']>p_high,
                    p_high,
                    np.where(new_df['P']<p_low,
                    p_low,
                    new_df['P']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['P'])

plt.subplot(2,2,2)
sns.boxplot(df['P'])

plt.subplot(2,2,3)
sns.distplot(new_df['P'])

plt.subplot(2,2,4)
sns.boxplot(new_df['P'])

plt.show()

# %%
K_high= q3.K+(1.5*IQR.K)
K_high
# Out:
# np.float64(95.0)

# %%
K_low= q1.K-(1.5*IQR.K)
K_low
# Out:
# np.float64(-25.0)

# %%
new_df['K']=np.where(new_df['K']>K_high,
                    K_high,
                    np.where(new_df['K']<K_low,
                    K_low,
                    new_df['K']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['K'])

plt.subplot(2,2,2)
sns.boxplot(df['K'])

plt.subplot(2,2,3)
sns.distplot(new_df['K'])

plt.subplot(2,2,4)
sns.boxplot(new_df['K'])

plt.show()

# %%
pH_high= q3.pH+(1.5*IQR.pH)
pH_high
# Out:
# np.float64(6.859999999999999)

# %%
pH_low= q1.pH-(1.5*IQR.pH)
pH_low
# Out:
# np.float64(4.460000000000001)

# %%
new_df['pH']=np.where(new_df['pH']>pH_high,
                   pH_high,
                    np.where(new_df['pH']<pH_low,
                    pH_low,
                    new_df['pH']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['pH'])

plt.subplot(2,2,2)
sns.boxplot(df['pH'])

plt.subplot(2,2,3)
sns.distplot(new_df['pH'])

plt.subplot(2,2,4)
sns.boxplot(new_df['pH'])

plt.show()

# %%
R_high= q3.rainfall+(1.5*IQR.rainfall)
R_high
# Out:
# np.float64(2540.9849999999997)

# %%
R_low= q1.rainfall-(1.5*IQR.rainfall)
R_low
# Out:
# np.float64(-1272.895)

# %%
new_df['rainfall']=np.where(new_df['rainfall']>R_high,
                   R_high,
                    np.where(new_df['rainfall']<R_low,
                    R_low,
                    new_df['rainfall']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['rainfall'])

plt.subplot(2,2,2)
sns.boxplot(df['rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df['rainfall'])

plt.subplot(2,2,4)
sns.boxplot(new_df['rainfall'])

plt.show()

# %%
T_high= q3.temperature+(1.5*IQR.temperature)
T_high
# Out:
# np.float64(38.50766666666667)

# %%
T_low= q1.temperature-(1.5*IQR.temperature)
T_low
# Out:
# np.float64(13.865)

# %%
new_df['temperature']=np.where(new_df['temperature']>T_high,
                   T_high,
                    np.where(new_df['temperature']<T_low,
                    T_low,
                    new_df['temperature']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['temperature'])

plt.subplot(2,2,2)
sns.boxplot(df['temperature'])

plt.subplot(2,2,3)
sns.distplot(new_df['temperature'])

plt.subplot(2,2,4)
sns.boxplot(new_df['temperature'])

plt.show()

# %%
A_high= q3.Area_in_hectares+(1.5*IQR.Area_in_hectares)
A_high
# Out:
# np.float64(20052.5)

# %%
A_low= q1.Area_in_hectares-(1.5*IQR.Area_in_hectares)
A_low
# Out:
# np.float64(-11823.5)

# %%
new_df['Area_in_hectares']=np.where(new_df['Area_in_hectares']>A_high,
                   A_high,
                    np.where(new_df['Area_in_hectares']<A_low,
                    A_low,
                    new_df['Area_in_hectares']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Area_in_hectares'])

plt.subplot(2,2,2)
sns.boxplot(df['Area_in_hectares'])

plt.subplot(2,2,3)
sns.distplot(new_df['Area_in_hectares'])

plt.subplot(2,2,4)
sns.boxplot(new_df['Area_in_hectares'])

plt.show()

# %%
Prod_high= q3.Production_in_tons+(1.5*IQR.Production_in_tons)
Prod_high
# Out:
# np.float64(35744.5)

# %%
Prod_low= q1.Production_in_tons-(1.5*IQR.Production_in_tons)
Prod_low
# Out:
# np.float64(-21187.5)

# %%
new_df['Production_in_tons']=np.where(new_df['Production_in_tons']>Prod_high,
                   Prod_high,
                    np.where(new_df['Production_in_tons']<Prod_low,
                    Prod_low,
                    new_df['Production_in_tons']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Production_in_tons'])

plt.subplot(2,2,2)
sns.boxplot(df['Production_in_tons'])

plt.subplot(2,2,3)
sns.distplot(new_df['Production_in_tons'])

plt.subplot(2,2,4)
sns.boxplot(new_df['Production_in_tons'])

plt.show()

# %%
Yield_high= q3.Yield_ton_per_hec+(1.5*IQR.Yield_ton_per_hec)
Yield_high
# Out:
# np.float64(6.613910207226002)

# %%
Yield_low= q1.Yield_ton_per_hec-(1.5*IQR.Yield_ton_per_hec)
Yield_low
# Out:
# np.float64(-3.030415089852843)

# %%
new_df['Yield_ton_per_hec']=np.where(new_df['Yield_ton_per_hec']>Yield_high,
                   Yield_high,
                    np.where(new_df['Yield_ton_per_hec']<Yield_low,
                    Yield_low,
                    new_df['Yield_ton_per_hec']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Yield_ton_per_hec'])

plt.subplot(2,2,2)
sns.boxplot(df['Yield_ton_per_hec'])

plt.subplot(2,2,3)
sns.distplot(new_df['Yield_ton_per_hec'])

plt.subplot(2,2,4)
sns.boxplot(new_df['Yield_ton_per_hec'])

plt.show()

# %%
plt.figure(figsize=(20, 12))
for i, column in enumerate(new_df.select_dtypes(include='number'),1):
    plt.subplot(4,4,i)
    sns.boxplot(new_df[column])
